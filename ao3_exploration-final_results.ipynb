# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#A-comparison-between-all-communities" data-toc-modified-id="A-comparison-between-all-communities-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>A comparison between all communities</a></span><ul class="toc-item"><li><span><a href="#Community-in-numbers" data-toc-modified-id="Community-in-numbers-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Community in numbers</a></span></li><li><span><a href="#Comparison-of-trends-and-Z-Score-in-LIWC’s-main-5-emotions" data-toc-modified-id="Comparison-of-trends-and-Z-Score-in-LIWC’s-main-5-emotions-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Comparison of trends and Z-Score in LIWC’s main 5 emotions</a></span></li><li><span><a href="#Comparison-of-the-histograms-of-the-5-main-emotions-of-LIWC" data-toc-modified-id="Comparison-of-the-histograms-of-the-5-main-emotions-of-LIWC-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Comparison of the histograms of the 5 main emotions of LIWC</a></span></li><li><span><a href="#Comparison-of-the-trends-in-number-of-comments,-text-length,-and-average-content-length" data-toc-modified-id="Comparison-of-the-trends-in-number-of-comments,-text-length,-and-average-content-length-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Comparison of the trends in number of comments, text length, and average content length</a></span></li><li><span><a href="#Final-results-of-bold-statements-from-scatter-plots,-correlation-matrices,-and-statement-in-general" data-toc-modified-id="Final-results-of-bold-statements-from-scatter-plots,-correlation-matrices,-and-statement-in-general-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Final results of bold statements from scatter plots, correlation matrices, and statement in general</a></span><ul class="toc-item"><li><span><a href="#Comparison-between-emotions-and-text-length-(by-comment)" data-toc-modified-id="Comparison-between-emotions-and-text-length-(by-comment)-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Comparison between emotions and text length (by comment)</a></span></li><li><span><a href="#Comparison-between-emotions-and-more-(by-work)" data-toc-modified-id="Comparison-between-emotions-and-more-(by-work)-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Comparison between emotions and more (by work)</a></span></li><li><span><a href="#Comparison-between-authors-on-their-works-and-others" data-toc-modified-id="Comparison-between-authors-on-their-works-and-others-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Comparison between authors on their works and others</a></span></li><li><span><a href="#Comparison-between-authors-on-their-works-and-authors-on-other's-works" data-toc-modified-id="Comparison-between-authors-on-their-works-and-authors-on-other's-works-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Comparison between authors on their works and authors on other's works</a></span></li></ul></li><li><span><a href="#Interweaving-with-Andrea's-work" data-toc-modified-id="Interweaving-with-Andrea's-work-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Interweaving with Andrea's work</a></span><ul class="toc-item"><li><span><a href="#Comparison-of-works" data-toc-modified-id="Comparison-of-works-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Comparison of works</a></span></li><li><span><a href="#Author-characterization-through-centrality-metrics" data-toc-modified-id="Author-characterization-through-centrality-metrics-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Author characterization through centrality metrics</a></span></li></ul></li><li><span><a href="#Divergence-among-communities" data-toc-modified-id="Divergence-among-communities-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Divergence among communities</a></span></li><li><span><a href="#The-trend-over-time-of-the-most-positive-and-negative-works-between-communities.-Do-you-see-any-similarities?" data-toc-modified-id="The-trend-over-time-of-the-most-positive-and-negative-works-between-communities.-Do-you-see-any-similarities?-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>The trend over time of the most positive and negative works between communities. Do you see any similarities?</a></span></li><li><span><a href="#Comparison-of-the-most-used-Posemo-and-Negemo-words-(author-on-own-works-vs-others)" data-toc-modified-id="Comparison-of-the-most-used-Posemo-and-Negemo-words-(author-on-own-works-vs-others)-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Comparison of the most used Posemo and Negemo words (author on own works vs others)</a></span><ul class="toc-item"><li><span><a href="#Posemo" data-toc-modified-id="Posemo-1.9.1"><span class="toc-item-num">1.9.1&nbsp;&nbsp;</span>Posemo</a></span><ul class="toc-item"><li><span><a href="#Author-on-own-works" data-toc-modified-id="Author-on-own-works-1.9.1.1"><span class="toc-item-num">1.9.1.1&nbsp;&nbsp;</span>Author on own works</a></span></li><li><span><a href="#Others" data-toc-modified-id="Others-1.9.1.2"><span class="toc-item-num">1.9.1.2&nbsp;&nbsp;</span>Others</a></span></li></ul></li><li><span><a href="#Negemo" data-toc-modified-id="Negemo-1.9.2"><span class="toc-item-num">1.9.2&nbsp;&nbsp;</span>Negemo</a></span><ul class="toc-item"><li><span><a href="#Author-on-own-works" data-toc-modified-id="Author-on-own-works-1.9.2.1"><span class="toc-item-num">1.9.2.1&nbsp;&nbsp;</span>Author on own works</a></span></li><li><span><a href="#Others" data-toc-modified-id="Others-1.9.2.2"><span class="toc-item-num">1.9.2.2&nbsp;&nbsp;</span>Others</a></span></li></ul></li></ul></li><li><span><a href="#Comparison-of-the-most-used-Posemo-and-Negemo-words-(author-on-own-works-vs-author-on-other's-works)" data-toc-modified-id="Comparison-of-the-most-used-Posemo-and-Negemo-words-(author-on-own-works-vs-author-on-other's-works)-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Comparison of the most used Posemo and Negemo words (author on own works vs author on other's works)</a></span><ul class="toc-item"><li><span><a href="#Posemo" data-toc-modified-id="Posemo-1.10.1"><span class="toc-item-num">1.10.1&nbsp;&nbsp;</span>Posemo</a></span><ul class="toc-item"><li><span><a href="#Author-on-own-works" data-toc-modified-id="Author-on-own-works-1.10.1.1"><span class="toc-item-num">1.10.1.1&nbsp;&nbsp;</span>Author on own works</a></span></li><li><span><a href="#Author-on-other's-works" data-toc-modified-id="Author-on-other's-works-1.10.1.2"><span class="toc-item-num">1.10.1.2&nbsp;&nbsp;</span>Author on other's works</a></span></li></ul></li><li><span><a href="#Negemo" data-toc-modified-id="Negemo-1.10.2"><span class="toc-item-num">1.10.2&nbsp;&nbsp;</span>Negemo</a></span><ul class="toc-item"><li><span><a href="#Author-on-own-works" data-toc-modified-id="Author-on-own-works-1.10.2.1"><span class="toc-item-num">1.10.2.1&nbsp;&nbsp;</span>Author on own works</a></span></li><li><span><a href="#Author-on-other's-works" data-toc-modified-id="Author-on-other's-works-1.10.2.2"><span class="toc-item-num">1.10.2.2&nbsp;&nbsp;</span>Author on other's works</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # A comparison between all communities

# %%
#%matplotlib notebook
# %matplotlib inline

from pymongo import MongoClient

import datetime

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

import numpy as np
from numpy import inf

import seaborn as sns

from scipy.stats import norm

import liwc
import re
from collections import Counter

import itertools

import math

import bar_chart_race as bcr

import warnings

sns.set_theme()

# %%
#For offline working

works_dfs = {}
works_collected_categories_desc = {}
ao3_comments_dfs = {}
liwc_categories_main = [ 'Posemo', 'Negemo', 'Anx', 'Anger', 'Sad', 'Ppron', 'I', 'SheHe', 'We', 'They', 'You', 'Ipron', 'Male', 'Female', 'See', 'Hear', 'Feel' ]
FANDOMS = [ 'marvel', 'harry_potter', 'sherlock_holmes', 'lord_of_the_rings', 'percy_jackson', 'twilight', 'warriors' ]
parse, category_names = liwc.load_token_parser('English_LIWC2015_Dictionary.dic')
def tokenize(text):
    # it is possible to use a smarter tokenizer
    for match in re.finditer(r'\w+', text, re.UNICODE):
        yield match.group(0)

# %%
#GLOBAL DEFINEMENTS - variables

#Part of the study related to the community
community_by_comment = {}
community_by_work = {}
community_by_author = {}
community_by_user = {}
community_by_author_only_text = {}
community_by_user_only_text = {}
authors = {}
authors_wid = {}
daily_stats = {}
total_stats = {}
monthly_stats = {}
daily_stats_by_work = {}
monthly_stats_by_work = {}
chapter_stats_by_work = {}
for fandom in FANDOMS:
    daily_stats_by_work[fandom] = {}
    monthly_stats_by_work[fandom] = {}
    chapter_stats_by_work[fandom] = {}
eligible_works = {}

categories_colors = {
    "Anger": "#ff0000",
    "Negemo": "#000000",
    "Posemo": "#ffb639",
    "Sad": "#3581b7",
    "Anx": "#8058a7"
}

#Part of the study related to the centrality of the author and the user more in general
authors_vs_others_comparison = {}
very_authors_vs_others_comparison = {}
author_vs_non_author_comparison = {}
author_vs_others_per_work = {}
author_vs_non_author = {}
word_frequency_author_vs_others_author = {}
word_frequency_author_vs_others_others = {}
word_frequency_author_vs_non_author_author = {}
word_frequency_author_vs_non_author_non_author = {}

#Interweaving with Andrea's work
first_comparison = {}
second_comparison = {}
third_comparison = {}

# %%
#GLOBAL DEFINEMENTS - functions

def f(x, y):
    if(x!=0):
        return round(x/y, 2)
    else:
        return 0.00

def plot_sma(df, category, polynomial_degree, rm1=20, rm2=50, rolling_mean=True, height=8, width=16, save_fig=False):
    plt.figure(figsize=(width, height))
    plt.plot(df.index, df[category], label=category)
    if(rolling_mean):
        rolling_mean1 = df[category].rolling(window=rm1).mean()
        rolling_mean2 = df[category].rolling(window=rm2).mean()
        plt.plot(df.index, rolling_mean1, label=f'{category} SMA - {rm1} rolling mean\'s window', color='orange')
        plt.plot(df.index, rolling_mean2, label=f'{category} SMA - {rm2} rolling mean\'s window', color='magenta')
    X = np.arange(0, len(df.index))
    z = np.polyfit(X, np.array(df[category]), polynomial_degree)
    p = np.poly1d(z)
    plt.plot(df.index, p(X), "--", color='black') #Trend Line
    plt.legend(loc='upper left')
    if save_fig:
        plt.savefig('pic', dpi=1200)
    plt.show()
    
def subplot_sma(plot, category, polynomial_degree, columns, rm1=20, rm2=50, rolling_mean=True, height=8, width=16):
    fig = plt.figure(figsize=(width, height))
    fig.subplots_adjust(wspace=0.07)
    for i in range(0, columns):
        ax = fig.add_subplot(1, columns, i+1)
        ax.plot(plot[i].index, plot[i][category], label=category)
        if(rolling_mean):
            rolling_mean1 = plot[i][category].rolling(window=rm1).mean()
            rolling_mean2 = plot[i][category].rolling(window=rm2).mean()
            ax.plot(plot[i].index, rolling_mean1, label=f'{category} SMA - {rm1} rolling mean\'s window', color='orange')
            ax.plot(plot[i].index, rolling_mean2, label=f'{category} SMA - {rm2} rolling mean\'s window', color='magenta')
        X = np.arange(0, len(plot[i].index))
        z = np.polyfit(X, np.array(plot[i][category]), polynomial_degree)
        p = np.poly1d(z)
        ax.plot(plot[i].index, p(X), "--", color='black') #Trend Line
        plt.legend(loc='upper left')

def plot_ema(df, category, polynomial_degree, w_exp1=20, w_exp2=50, exp=True, height=8, width=16):    
    plt.figure(figsize=(width, height))
    plt.plot(df.index, df[category], label=category)
    if(exp):
        exp1 = df[category].ewm(span=w_exp1, adjust=False).mean()
        exp2 = df[category].ewm(span=w_exp2, adjust=False).mean()
        plt.plot(df.index, exp1, label=f'{category} EMA - {w_exp1} exp\'s window')
        plt.plot(df.index, exp2, label=f'{category} EMA - {w_exp2} exp\'s window')
    X = np.arange(0, len(df.index))
    z = np.polyfit(X, np.array(df[category]), polynomial_degree)
    p = np.poly1d(z)
    plt.plot(df.index, p(X), "--", color='black') #Trend Line
    plt.legend(loc='upper left')
    plt.show()
    
def subplot_ema(plot, category, polynomial_degree, columns, w_exp1=20, w_exp2=50, exp=True, height=8, width=16):
    fig = plt.figure(figsize=(width, height))
    fig.subplots_adjust(wspace=0.07)
    for i in range(0, columns):
        ax = fig.add_subplot(1, columns, i+1)
        ax.plot(plot[i].index, plot[i][category], label=category)
        if(exp):
            exp1 = plot[i][category].ewm(span=w_exp1, adjust=False).mean()
            exp2 = plot[i][category].ewm(span=w_exp2, adjust=False).mean()
            plt.plot(plot[i].index, exp1, label=f'{category} EMA - {w_exp1} exp\'s window')
            plt.plot(plot[i].index, exp2, label=f'{category} EMA - {w_exp2} exp\'s window')
        X = np.arange(0, len(plot[i].index))
        z = np.polyfit(X, np.array(plot[i][category]), polynomial_degree)
        p = np.poly1d(z)
        ax.plot(plot[i].index, p(X), "--", color='black') #Trend Line
        plt.legend(loc='upper left')

def plt_corr(df, y_ax, x_ax, title, log_scale=False, xlog_scale=False, ylog_scale=False, xlim=0.1, ylim=0.1, polyfit=False, height=8, width=16):
    fig, ax = plt.subplots(figsize=(width, height))
    x = np.array(df[x_ax])
    y = np.array(df[y_ax])
    plt.scatter(x, y,
                edgecolor='black', linewidth=1, alpha=0.75)
    if(xlog_scale):
        plt.gca().set_xscale('log')
    if(ylog_scale):
        plt.gca().set_yscale('log')
    if(log_scale):
        plt.loglog()
    if(xlog_scale or ylog_scale or log_scale):
        for axis in [ax.xaxis, ax.yaxis]:
            axis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)
    if(polyfit):
        z = np.polyfit(x, y, 1)
        p = np.poly1d(z)
        plt.plot(x,p(x),"r--")
    plt.xlabel(x_ax)
    plt.ylabel(y_ax)
    plt.title(title)
    plt.tight_layout()
    plt.show()

def plot_zscore(df, pair, height=8, width=16):
    plt.figure(figsize=(width, height))
    for category in pair:
        plt.plot(
            df.index,
            (df[category] - df[category].mean())
            / df[category].std(),
            color=categories_colors[category],
            label=category,
        )
    plt.legend(
        bbox_to_anchor=(0.0, 1.02, 1.0, 0.102),
        loc="lower left",
        ncol=4,
        mode="expand",
        borderaxespad=0.0,
    )
    
def subplot_zscore(plot, pair, columns, height=8, width=16):
    fig = plt.figure(figsize=(width, height))
    fig.subplots_adjust(wspace=0.07)
    for i in range(0, columns):
        ax = fig.add_subplot(1, columns, i+1)
        for category in pair:
            plt.plot(
                plot[i].index,
                (plot[i][category] - plot[i][category].mean())
                / plot[i][category].std(),
                color=categories_colors[category],
                label=category,
            )
        plt.legend(
            bbox_to_anchor=(0.0, 1.02, 1.0, 0.102),
            loc="lower left",
            ncol=4,
            mode="expand",
            borderaxespad=0.0,
        )
    
def plot_histogram_density_function(variable, title, xlabel, ylim, bins, height=8, width=16):
    fig, ax = plt.subplots(figsize=(width, height))
    variable.plot(kind="hist", bins=bins)
    #X
    ax.set_xlabel(xlabel)
    ax.set_xlim(0)
    ax.set_title(title[0])
    plt.show()

    fig, ax = plt.subplots(figsize=(width, height))
    #Plot histogram
    variable.plot(kind="hist", density=True, bins=bins, alpha=0.7) #change density to true, because KDE uses density
    #Plot KDE
    variable.plot(kind="kde", color='red')
    #X
    ax.set_xlabel(xlabel)
    ax.set_xlim(0)
    #Y
    ax.set_ylim(0, ylim)
    ax.set_title(title[1])
    plt.show()

    fig, ax = plt.subplots(figsize=(width, height))
    #Plot histogram
    variable.plot(kind="hist", density=True, bins=bins, alpha=0.7, label='_nolegend_') #change density to true, because KDE uses density
    #Plot KDE
    variable.plot(kind="kde", color='red', label='_nolegend_')
    #Quantile lines
    quant_5, quant_25, quant_50, quant_75, quant_95 = variable.quantile(0.05), variable.quantile(0.25), variable.quantile(0.5), variable.quantile(0.75), variable.quantile(0.95)
    quants = [[quant_5, 0.6, 0.16], [quant_25, 0.8, 0.26], [quant_50, 1, 0.36],  [quant_75, 0.8, 0.46], [quant_95, 0.6, 0.56]]
    quants_label = [ '5th', '25th', '50th', '75th', '95th']
    for i, label in zip(quants,quants_label):
        ax.axvline(i[0], alpha = i[1], ymax = i[2], linestyle = "--", linewidth=3, color='black', label=label)
    #X
    ax.set_xlabel(xlabel)
    ax.set_xlim(0)
    #Y
    ax.set_ylim(0, ylim)
    ax.set_yticklabels([])
    ax.set_ylabel("Frequency")
    ax.grid(False)
    ax.set_title(title[2])
    #Remove ticks and spines
    ax.tick_params(left=False, bottom=False)
    for ax, spine in ax.spines.items():
        spine.set_visible(False)
    plt.legend(loc=0)
    plt.show()
    
matplotlib.rcParams['animation.embed_limit'] = 2**128
def bar_chart_race(df):
    warnings.filterwarnings('ignore')
    selected_columns = df[['Posemo','Negemo','Anx','Anger','Sad']]
    new_df = selected_columns.copy()
    df = pd.DataFrame(new_df)
    df.index = pd.to_datetime(df.index)
    html = bcr.bar_chart_race(df, title='Emotional trends over time', period_fmt='%b %d, %Y')
    warnings.filterwarnings('default')
    return html

def calculate_percentages_avg(df):
    for i, row in df.iterrows():
        for category in liwc_categories_main:
            ifor_val = 0.00
            if row[category] != 0:
                    ifor_val = round(((row[category] / row['text_length']) * 100), 2)
            df.at[i,category] = ifor_val
    df['average_content_length'] = df.apply(lambda x: f(x.text_length, x.ncomments), axis=1)
    cols = df.columns.tolist()
    cols = cols[0:2] + cols[-1:] + cols[2:19]
    df = df[cols]
    return df

def show_distance(calculation_df, title, label_auth, label_non_auth, change_ylim=False):
    my_range=range(1,len(calculation_df.index)+1)
    plt.figure(figsize=(16, 8))
    plt.hlines(y=my_range, xmin=calculation_df['author'], xmax=calculation_df['non-author'], color='grey', alpha=0.4)
    plt.scatter(calculation_df['author'], my_range, color='navy', alpha=1, label=label_auth)
    plt.scatter(calculation_df['non-author'], my_range, color='gold', alpha=0.8, label=label_non_auth)
    plt.legend()
    plt.yticks(my_range, calculation_df['index'])
    if(change_ylim):
        ax = plt.gca()
        ax.set_xlim([0,max(float(calculation_df['non-author']),float(calculation_df['author']))+abs((float(calculation_df['non-author'])-float(calculation_df['author'])))])
    plt.title(title, loc='left')
    plt.xlabel('Value of the Positions')
    plt.ylabel('Categories')
    plt.show()
    
def bar_chart(df, title, fmt='%.0f', width=0.1, fig_width=16, fig_height=8):
    # plot bars or kind='barh' for horizontal bars; adjust figsize accordingly
    ax = df.plot(kind='barh', title=title, width=width, figsize=(fig_width, fig_height))
    ax.set(xlabel='Size')
    ax.set(ylabel='Branch')
    # add some labels
#     for c in ax.containers:
#         # set the bar label
#         ax.bar_label(c, fmt=fmt, label_type='edge')
    # add a little space at the top of the plot for the annotation
    ax.margins(x=0.1)
    # move the legend out of the plot
    ax.legend(bbox_to_anchor=(1, 1.02), loc='upper left')

# %%
#For offline working

for fandom in FANDOMS:
    print(f"Creating dataframes in {fandom}...")
    
    df = pd.read_csv(f'{fandom}_works_dfs.csv')
    df = df.drop([df.columns[0]], axis=1)
    works_dfs[fandom] = df
    
    df = pd.read_csv(f'{fandom}_works_collected_categories_desc.csv')
    df = df.drop([df.columns[0]], axis=1)
    works_collected_categories_desc[fandom] = df
    
    df = pd.read_csv(f'{fandom}_ao3_comments_dfs.csv')
    df = df.drop([df.columns[0]], axis=1)
    df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
    df['text'] = df['text'].astype(str)
    ao3_comments_dfs[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_author_vs_non_author.csv').set_index('author')
    author_vs_non_author[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_author_vs_non_author_comparison.csv')
    df = df.drop([df.columns[0]], axis=1)
    author_vs_non_author_comparison[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_author_vs_others_per_work.csv').set_index('work_id')
    author_vs_others_per_work[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_authors_vs_others_comparison.csv')
    df = df.drop([df.columns[0]], axis=1)
    authors_vs_others_comparison[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_community_by_author.csv').groupby(['comment_author', 'work_id']).sum()
    community_by_author[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_community_by_comment.csv')
    df = df.drop([df.columns[0]], axis=1).set_index('datetime')
    community_by_comment[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_community_by_user.csv').groupby(['comment_author', 'work_id']).sum()
    community_by_user[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_community_by_work.csv').set_index('work_id')
    community_by_work[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_daily_stats.csv').set_index('date')
    daily_stats[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_monthly_stats.csv').set_index('date')
    monthly_stats[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_total_stats.csv')
    df = df.drop([df.columns[0]], axis=1)
    total_stats[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_very_authors_vs_others_comparison.csv')
    df = df.drop([df.columns[0]], axis=1)
    very_authors_vs_others_comparison[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_word_frequency_author_vs_non_author_author.csv')
    df = df.drop([df.columns[0]], axis=1)
    word_frequency_author_vs_non_author_author[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_word_frequency_author_vs_non_author_non_author.csv')
    df = df.drop([df.columns[0]], axis=1)
    word_frequency_author_vs_non_author_non_author[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_word_frequency_author_vs_others_author.csv')
    df = df.drop([df.columns[0]], axis=1)
    word_frequency_author_vs_others_author[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_word_frequency_author_vs_others_others.csv')
    df = df.drop([df.columns[0]], axis=1)
    word_frequency_author_vs_others_others[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_first_comparison.csv')
    first_comparison[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_second_comparison.csv')
    second_comparison[fandom] = df
    
    df = pd.read_csv(f'./{fandom}/{fandom}_third_comparison.csv')
    third_comparison[fandom] = df
# Out:
# Creating dataframes in marvel...
# Creating dataframes in harry_potter...
# Creating dataframes in sherlock_holmes...
# Creating dataframes in lord_of_the_rings...
# Creating dataframes in percy_jackson...
# Creating dataframes in twilight...
# Creating dataframes in warriors...

# %% [markdown]
# ## Community in numbers

# %%
pd.DataFrame(list(zip([fandom for fandom in FANDOMS],
                      [len(community_by_work[fandom].index) for fandom in FANDOMS],
                      [(len(community_by_user[fandom].index.get_level_values('comment_author'))+len(community_by_author[fandom].index.get_level_values('comment_author'))) for fandom in FANDOMS],
                      [len(community_by_author[fandom].index.get_level_values('comment_author')) for fandom in FANDOMS],
                      [len(community_by_comment[fandom].index) for fandom in FANDOMS]
                     )
                 ),
             columns=['Community', 'Number of Works', 'Number of Users', 'Number of Authors', 'Number of Comments'])
# Out:
#            Community  Number of Works  Number of Users  Number of Authors  \
# 0             marvel           295172          4592163            1718165
# 1       harry_potter           153505          2534172             699432
# 2    sherlock_holmes            69712          1048751             406434
# 3  lord_of_the_rings            10650           106235              27601
# 4      percy_jackson            12296           136802              30538
# 5           twilight             5452            59907               8515
# 6           warriors             1302             8226               2426
#
#    Number of Comments
# 0            10946620
# 1             6350061
# 2             2749016
# 3              289388
# 4              311157
# 5              141402
# 6               24472

# %% [markdown]
# ## Comparison of trends and Z-Score in LIWC’s main 5 emotions

# %% [markdown]
# ## Comparison of the histograms of the 5 main emotions of LIWC

# %% [markdown]
# ## Comparison of the trends in number of comments, text length, and average content length

# %% [markdown]
# ## Final results of bold statements from scatter plots, correlation matrices, and statement in general

# %% [markdown]
# ### Comparison between emotions and text length (by comment)

# %%
aggregate = []

for fandom in FANDOMS:
    data = {'Text length': community_by_comment[fandom][community_by_comment[fandom]['text_length']>50]['text_length'],
            'Posemo': community_by_comment[fandom][community_by_comment[fandom]['text_length']>50]['Posemo'],
            'Negemo': community_by_comment[fandom][community_by_comment[fandom]['text_length']>50]['Negemo'],
            'Anx': community_by_comment[fandom][community_by_comment[fandom]['text_length']>50]['Anx'],
            'Anger': community_by_comment[fandom][community_by_comment[fandom]['text_length']>50]['Anger'],
            'Sad': community_by_comment[fandom][community_by_comment[fandom]['text_length']>50]['Sad']
            }
    df = pd.DataFrame(data,columns=['Text length',
                                    'Number of comments',
                                    'Average content length',
                                    'Posemo', 
                                    'Negemo', 
                                    'Anx', 
                                    'Anger', 
                                    'Sad',
                                    'Kudos'
                                   ])
    corrMatrix = df.corr()
    aggregate.append(corrMatrix)

corrMatrix = pd.concat(([df for df in aggregate])).groupby(pd.concat(([df for df in aggregate])).index).mean().reindex(index = list(corrMatrix.index))
plt.figure(figsize=(16, 8))
sns.heatmap(corrMatrix, vmin=-1, vmax=1, cmap="vlag_r", annot=True)
plt.show()

# %% [markdown]
# ### Comparison between emotions and more (by work)

# %%
nkudos = {}
for fandom in FANDOMS:
    _nkudos = []
    for work in community_by_work[fandom][community_by_work[fandom]['text_length']>50].index:
        row_index = works_dfs[fandom].index[works_dfs[fandom]["id"] == work].tolist()[0]
        _nkudos.append(works_dfs[fandom]['nkudos'][row_index])
    nkudos[fandom] = _nkudos

aggregate = []

for fandom in FANDOMS:
    data = {'Text length': community_by_work[fandom][community_by_work[fandom]['text_length']>50]['text_length'],
        'Number of comments': community_by_work[fandom][community_by_work[fandom]['text_length']>50]['ncomments'],
        'Average content length': community_by_work[fandom][community_by_work[fandom]['text_length']>50]['average_content_length'],
        'Posemo': community_by_work[fandom][community_by_work[fandom]['text_length']>50]['Posemo'],
        'Negemo': community_by_work[fandom][community_by_work[fandom]['text_length']>50]['Negemo'],
        'Anx': community_by_work[fandom][community_by_work[fandom]['text_length']>50]['Anx'],
        'Anger': community_by_work[fandom][community_by_work[fandom]['text_length']>50]['Anger'],
        'Sad': community_by_work[fandom][community_by_work[fandom]['text_length']>50]['Sad'],
        'Kudos': nkudos[fandom]
        }
    df = pd.DataFrame(data,columns=['Text length',
                                    'Number of comments',
                                    'Average content length',
                                    'Posemo', 
                                    'Negemo', 
                                    'Anx', 
                                    'Anger', 
                                    'Sad',
                                    'Kudos'
                                   ])
    corrMatrix = df.corr()
    aggregate.append(corrMatrix)
    
corrMatrix = pd.concat(([df for df in aggregate])).groupby(pd.concat(([df for df in aggregate])).index).mean().reindex(index = list(corrMatrix.index))
plt.figure(figsize=(16, 8))
sns.heatmap(corrMatrix, vmin=-1, vmax=1, cmap="vlag_r", annot=True)
plt.show()

# %% [markdown]
# ### Comparison between authors on their works and others

# %%
aggregate = []

for fandom in FANDOMS:
    mask1 = (author_vs_others_per_work[fandom]['text_length_author']>50) & (author_vs_others_per_work[fandom]['text_length_others']>50)
    data = {'Author text_length': author_vs_others_per_work[fandom][mask1]['text_length_author'], 
            'Author ncomments': author_vs_others_per_work[fandom][mask1]['ncomments_author'], 
            'Author average_content_length': author_vs_others_per_work[fandom][mask1]['average_content_length_author'], 
            'Author Posemo': author_vs_others_per_work[fandom][mask1]['Posemo_author'], 
            'Author Negemo': author_vs_others_per_work[fandom][mask1]['Negemo_author'], 
            'Author Anx': author_vs_others_per_work[fandom][mask1]['Anx_author'], 
            'Author Anger': author_vs_others_per_work[fandom][mask1]['Anger_author'], 
            'Author Sad': author_vs_others_per_work[fandom][mask1]['Sad_author'], 
            'Others text_length': author_vs_others_per_work[fandom][mask1]['text_length_others'], 
            'Others ncomments': author_vs_others_per_work[fandom][mask1]['ncomments_others'], 
            'Others average_content_length': author_vs_others_per_work[fandom][mask1]['average_content_length_others'], 
            'Others Posemo': author_vs_others_per_work[fandom][mask1]['Posemo_others'], 
            'Others Negemo': author_vs_others_per_work[fandom][mask1]['Negemo_others'], 
            'Others Anx': author_vs_others_per_work[fandom][mask1]['Anx_others'], 
            'Others Anger': author_vs_others_per_work[fandom][mask1]['Anger_others'], 
            'Others Sad': author_vs_others_per_work[fandom][mask1]['Sad_others']
            }
    df = pd.DataFrame(data,columns=['Author text_length', 
                                    'Author ncomments', 
                                    'Author average_content_length', 
                                    'Author Posemo', 
                                    'Author Negemo', 
                                    'Author Anx', 
                                    'Author Anger', 
                                    'Author Sad', 
                                    'Others text_length', 
                                    'Others ncomments', 
                                    'Others average_content_length', 
                                    'Others Posemo', 
                                    'Others Negemo', 
                                    'Others Anx', 
                                    'Others Anger', 
                                    'Others Sad'
                                   ])
    corrMatrix = df.corr()
    aggregate.append(corrMatrix)

corrMatrix = pd.concat(([df for df in aggregate])).groupby(pd.concat(([df for df in aggregate])).index).mean().reindex(index = list(corrMatrix.index))
plt.figure(figsize=(32, 16))
sns.heatmap(corrMatrix, vmin=-1, vmax=1, cmap="vlag_r", annot=True)
plt.show()

# %% [markdown]
# ### Comparison between authors on their works and authors on other's works

# %%
aggregate = []

for fandom in FANDOMS:
    mask2 = (author_vs_non_author[fandom]['text_length_author']>50) & (author_vs_non_author[fandom]['text_length_non_author']>50)
    data = {'Author on own works text_length': author_vs_non_author[fandom][mask2]['text_length_author'], 
            'Author on own works ncomments': author_vs_non_author[fandom][mask2]['ncomments_author'], 
            'Author on own works average_content_length': author_vs_non_author[fandom][mask2]['average_content_length_author'], 
            'Author on own works Posemo': author_vs_non_author[fandom][mask2]['Posemo_author'], 
            'Author on own works Negemo': author_vs_non_author[fandom][mask2]['Negemo_author'], 
            'Author on own works Anx': author_vs_non_author[fandom][mask2]['Anx_author'], 
            'Author on own works Anger': author_vs_non_author[fandom][mask2]['Anger_author'], 
            'Author on own works Sad': author_vs_non_author[fandom][mask2]['Sad_author'], 
            'Author on other’s works text_length': author_vs_non_author[fandom][mask2]['text_length_non_author'], 
            'Author on other’s works ncomments': author_vs_non_author[fandom][mask2]['ncomments_non_author'], 
            'Author on other’s works average_content_length': author_vs_non_author[fandom][mask2]['average_content_length_non_author'], 
            'Author on other’s works Posemo': author_vs_non_author[fandom][mask2]['Posemo_non_author'], 
            'Author on other’s works Negemo': author_vs_non_author[fandom][mask2]['Negemo_non_author'], 
            'Author on other’s works Anx': author_vs_non_author[fandom][mask2]['Anx_non_author'], 
            'Author on other’s works Anger': author_vs_non_author[fandom][mask2]['Anger_non_author'], 
            'Author on other’s works Sad': author_vs_non_author[fandom][mask2]['Sad_non_author']
           }
    df = pd.DataFrame(data,columns=['Author on own works text_length', 
                                    'Author on own works ncomments', 
                                    'Author on own works average_content_length', 
                                    'Author on own works Posemo', 
                                    'Author on own works Negemo', 
                                    'Author on own works Anx', 
                                    'Author on own works Anger', 
                                    'Author on own works Sad', 
                                    'Author on other’s works text_length', 
                                    'Author on other’s works ncomments', 
                                    'Author on other’s works average_content_length', 
                                    'Author on other’s works Posemo', 
                                    'Author on other’s works Negemo', 
                                    'Author on other’s works Anx', 
                                    'Author on other’s works Anger', 
                                    'Author on other’s works Sad'
                                   ])
    corrMatrix = df.corr()
    aggregate.append(corrMatrix)

corrMatrix = pd.concat(([df for df in aggregate])).groupby(pd.concat(([df for df in aggregate])).index).mean().reindex(index = list(corrMatrix.index))
plt.figure(figsize=(32, 16))
sns.heatmap(corrMatrix, vmin=-1, vmax=1, cmap="vlag_r", annot=True)
plt.show()

# %% [markdown]
# ## Interweaving with Andrea's work

# %% [markdown]
# ### Comparison of works

# %%
aggregate = []

for fandom in FANDOMS:
    aggregate.append(first_comparison[fandom])

corrMatrix = pd.DataFrame()
corrMatrix = pd.concat(([df for df in aggregate])).set_index('Unnamed: 0')
corrMatrix = corrMatrix.groupby(corrMatrix.index).mean().reindex(index = list(corrMatrix.columns))
corrMatrix.index.name = None
plt.figure(figsize=(32, 16))
sns.heatmap(corrMatrix, vmin=-1, vmax=1, cmap="vlag_r", annot=True)
plt.show()

# %%
aggregate = []

for fandom in FANDOMS:
    aggregate.append(second_comparison[fandom])

corrMatrix = pd.DataFrame()
corrMatrix = pd.concat(([df for df in aggregate])).set_index('Unnamed: 0')
corrMatrix = corrMatrix.groupby(corrMatrix.index).mean().reindex(index = list(corrMatrix.columns))
corrMatrix.index.name = None
plt.figure(figsize=(32, 16))
sns.heatmap(corrMatrix, vmin=-1, vmax=1, cmap="vlag_r", annot=True)
plt.show()

# %% [markdown]
# ### Author characterization through centrality metrics

# %%
aggregate = []

for fandom in FANDOMS:
    aggregate.append(third_comparison[fandom])

corrMatrix = pd.DataFrame()
corrMatrix = pd.concat(([df for df in aggregate])).set_index('Unnamed: 0')
corrMatrix = corrMatrix.groupby(corrMatrix.index).mean().reindex(index = list(corrMatrix.columns))
corrMatrix.index.name = None
plt.figure(figsize=(32, 16))
sns.heatmap(corrMatrix, vmin=-1, vmax=1, cmap="vlag_r", annot=True)
plt.show()

# %% [markdown]
# ## Divergence among communities

# %% [markdown]
# - mean, std and variance dell'analisi preliminare
# - score_diff della author centrality

# %% [markdown]
# ## The trend over time of the most positive and negative works between communities. Do you see any similarities?

# %% [markdown]
# ## Comparison of the most used Posemo and Negemo words (author on own works vs others)

# %% [markdown]
# ### Posemo

# %% [markdown]
# #### Author on own works

# %%
aggregate = pd.DataFrame()

for fandom in FANDOMS:
    aggregate = pd.concat([aggregate, word_frequency_author_vs_others_author[fandom]])

res = aggregate.groupby(['word','categories']).sum().reset_index()
    
res = res[res['categories'].str.contains("Posemo")].sort_values(by=['frequency'], ascending=False).head(10).reset_index()
res = res.drop([res.columns[0]], axis=1)
res.index = np.arange(1, len(res) + 1)
res
# Out:
#        word                                         categories  frequency
# 1      glad                                  Adj Affect Posemo    1256585
# 2     thank                    Verb Affect Posemo FocusPresent     942333
# 3      love        Affect Posemo Social Bio Drives Affiliation     626673
# 4   enjoyed                                      Affect Posemo     504877
# 5     liked                       Verb Affect Posemo FocusPast     473990
# 6     happy                                  Adj Affect Posemo     435633
# 7      good                        Affect Posemo Drives Reward     340083
# 8      hope  Verb Affect Posemo CogProc Discrep Tentat Focu...     340079
# 9      well      Function Adverb Affect Posemo Informal Nonflu     322267
# 10     kind                                      Affect Posemo     273159

# %% [markdown]
# #### Others

# %%
aggregate = pd.DataFrame()

for fandom in FANDOMS:
    aggregate = pd.concat([aggregate, word_frequency_author_vs_others_others[fandom]])

res = aggregate.groupby(['word','categories']).sum().reset_index()
    
res = res[res['categories'].str.contains("Posemo")].sort_values(by=['frequency'], ascending=False).head(10).reset_index()
res = res.drop([res.columns[0]], axis=1)
res.index = np.arange(1, len(res) + 1)
res
# Out:
#        word                                         categories  frequency
# 1      love        Affect Posemo Social Bio Drives Affiliation     146895
# 2      good                        Affect Posemo Drives Reward      56529
# 3      well      Function Adverb Affect Posemo Informal Nonflu      38627
# 4     great                    Adj Affect Posemo Drives Reward      34606
# 5     loved        Affect Posemo Social Bio Drives Affiliation      34226
# 6      cute                                  Adj Affect Posemo      27824
# 7      hope  Verb Affect Posemo CogProc Discrep Tentat Focu...      26605
# 8   amazing                                  Adj Affect Posemo      25951
# 9     sweet               Adj Affect Posemo Percept Bio Ingest      23991
# 10    happy                                  Adj Affect Posemo      19723

# %% [markdown]
# ### Negemo

# %% [markdown]
# #### Author on own works

# %%
aggregate = pd.DataFrame()

for fandom in FANDOMS:
    aggregate = pd.concat([aggregate, word_frequency_author_vs_others_author[fandom]])

res = aggregate.groupby(['word','categories']).sum().reset_index()
    
res = res[res['categories'].str.contains("Negemo")].sort_values(by=['frequency'], ascending=False).head(10).reset_index()
res = res.drop([res.columns[0]], axis=1)
res.index = np.arange(1, len(res) + 1)
res
# Out:
#      word                                   categories  frequency
# 1   sorry                        Adj Affect Negemo Sad     173597
# 2     bad                    Affect Negemo Drives Risk     103144
# 3   worry          Verb Affect Negemo Anx FocusPresent      79329
# 4    poor         Adj Affect Negemo Drives Power Money      55780
# 5   wrong                Adj Affect Negemo Drives Risk      50126
# 6     sad                        Adj Affect Negemo Sad      49471
# 7    hurt               Affect Negemo Sad Percept Feel      40973
# 8    shit  Affect Negemo Anger Bio Body Informal Swear      40969
# 9    hate        Verb Affect Negemo Anger FocusPresent      40811
# 10  weird                            Adj Affect Negemo      37018

# %% [markdown]
# #### Others

# %%
aggregate = pd.DataFrame()

for fandom in FANDOMS:
    aggregate = pd.concat([aggregate, word_frequency_author_vs_others_others[fandom]])

res = aggregate.groupby(['word','categories']).sum().reset_index()
    
res = res[res['categories'].str.contains("Negemo")].sort_values(by=['frequency'], ascending=False).head(10).reset_index()
res = res.drop([res.columns[0]], axis=1)
res.index = np.arange(1, len(res) + 1)
res
# Out:
#        word                                         categories  frequency
# 1       sad                              Adj Affect Negemo Sad      11010
# 2       bad                          Affect Negemo Drives Risk       9384
# 3      poor               Adj Affect Negemo Drives Power Money       7768
# 4     sorry                              Adj Affect Negemo Sad       7193
# 5      shit        Affect Negemo Anger Bio Body Informal Swear       5626
# 6   fucking  Adj Affect Negemo Anger Bio Sexual Informal Swear       5458
# 7      hurt                     Affect Negemo Sad Percept Feel       5395
# 8       cry                             Verb Affect Negemo Sad       5243
# 9     wrong                      Adj Affect Negemo Drives Risk       5177
# 10   crying                             Verb Affect Negemo Sad       5005

# %% [markdown]
# ## Comparison of the most used Posemo and Negemo words (author on own works vs author on other's works)

# %% [markdown]
# ### Posemo

# %% [markdown]
# #### Author on own works

# %%
aggregate = pd.DataFrame()

for fandom in FANDOMS:
    aggregate = pd.concat([aggregate, word_frequency_author_vs_non_author_author[fandom]])

res = aggregate.groupby(['word','categories']).sum().reset_index()
    
res = res[res['categories'].str.contains("Posemo")].sort_values(by=['frequency'], ascending=False).head(10).reset_index()
res = res.drop([res.columns[0]], axis=1)
res.index = np.arange(1, len(res) + 1)
res
# Out:
#        word                                         categories  frequency
# 1      glad                                  Adj Affect Posemo    1256585
# 2     thank                    Verb Affect Posemo FocusPresent     942333
# 3      love        Affect Posemo Social Bio Drives Affiliation     626673
# 4   enjoyed                                      Affect Posemo     504877
# 5     liked                       Verb Affect Posemo FocusPast     473990
# 6     happy                                  Adj Affect Posemo     435633
# 7      good                        Affect Posemo Drives Reward     340083
# 8      hope  Verb Affect Posemo CogProc Discrep Tentat Focu...     340079
# 9      well      Function Adverb Affect Posemo Informal Nonflu     322267
# 10     kind                                      Affect Posemo     273159

# %% [markdown]
# #### Author on other's works

# %%
aggregate = pd.DataFrame()

for fandom in FANDOMS:
    aggregate = pd.concat([aggregate, word_frequency_author_vs_non_author_non_author[fandom]])

res = aggregate.groupby(['word','categories']).sum().reset_index()
    
res = res[res['categories'].str.contains("Posemo")].sort_values(by=['frequency'], ascending=False).head(10).reset_index()
res = res.drop([res.columns[0]], axis=1)
res.index = np.arange(1, len(res) + 1)
res
# Out:
#        word                                         categories  frequency
# 1      love        Affect Posemo Social Bio Drives Affiliation    1318838
# 2      good                        Affect Posemo Drives Reward     438015
# 3      well      Function Adverb Affect Posemo Informal Nonflu     330482
# 4     loved        Affect Posemo Social Bio Drives Affiliation     311233
# 5     great                    Adj Affect Posemo Drives Reward     253640
# 6   amazing                                  Adj Affect Posemo     210062
# 7     sweet               Adj Affect Posemo Percept Bio Ingest     187565
# 8      hope  Verb Affect Posemo CogProc Discrep Tentat Focu...     182749
# 9   perfect  Adj Affect Posemo CogProc Certain Drives Rewar...     178782
# 10    happy                                  Adj Affect Posemo     178560

# %% [markdown]
# ### Negemo

# %% [markdown]
# #### Author on own works

# %%
aggregate = pd.DataFrame()

for fandom in FANDOMS:
    aggregate = pd.concat([aggregate, word_frequency_author_vs_non_author_author[fandom]])

res = aggregate.groupby(['word','categories']).sum().reset_index()
    
res = res[res['categories'].str.contains("Negemo")].sort_values(by=['frequency'], ascending=False).head(10).reset_index()
res = res.drop([res.columns[0]], axis=1)
res.index = np.arange(1, len(res) + 1)
res
# Out:
#      word                                   categories  frequency
# 1   sorry                        Adj Affect Negemo Sad     173597
# 2     bad                    Affect Negemo Drives Risk     103144
# 3   worry          Verb Affect Negemo Anx FocusPresent      79329
# 4    poor         Adj Affect Negemo Drives Power Money      55780
# 5   wrong                Adj Affect Negemo Drives Risk      50126
# 6     sad                        Adj Affect Negemo Sad      49471
# 7    hurt               Affect Negemo Sad Percept Feel      40973
# 8    shit  Affect Negemo Anger Bio Body Informal Swear      40969
# 9    hate        Verb Affect Negemo Anger FocusPresent      40811
# 10  weird                            Adj Affect Negemo      37018

# %% [markdown]
# #### Author on other's works

# %%
aggregate = pd.DataFrame()

for fandom in FANDOMS:
    aggregate = pd.concat([aggregate, word_frequency_author_vs_non_author_non_author[fandom]])

res = aggregate.groupby(['word','categories']).sum().reset_index()
    
res = res[res['categories'].str.contains("Negemo")].sort_values(by=['frequency'], ascending=False).head(10).reset_index()
res = res.drop([res.columns[0]], axis=1)
res.index = np.arange(1, len(res) + 1)
res
# Out:
#        word                                         categories  frequency
# 1      poor               Adj Affect Negemo Drives Power Money      87655
# 2       bad                          Affect Negemo Drives Risk      82692
# 3       sad                              Adj Affect Negemo Sad      80019
# 4   fucking  Adj Affect Negemo Anger Bio Sexual Informal Swear      77424
# 5      shit        Affect Negemo Anger Bio Body Informal Swear      66468
# 6      hurt                     Affect Negemo Sad Percept Feel      57382
# 7     sorry                              Adj Affect Negemo Sad      53291
# 8      damn                 Affect Negemo Anger Informal Swear      52019
# 9      fuck  Verb Affect Negemo Anger Bio Sexual FocusPrese...      47597
# 10    wrong                      Adj Affect Negemo Drives Risk      46362
